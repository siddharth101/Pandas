# %%
import os
import pandas as pd
import numpy as np

# %%
df_movies = pd.read_csv('../files/movie_metadata.csv')

# %%
df_movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# ## Accessing rows, rows and columns
# To access rows we can use iloc and loc
# iloc integer location based while loc uses label based indexing. In the current dataframe, both will yield the same result

# %%
### Selecting one row and all columns
df_movies.iloc[0,:] # same as df_movies.iloc[0]
# Out:
# color                                                                    Color
# director_name                                                    James Cameron
# num_critic_for_reviews                                                     723
# duration                                                                   178
# director_facebook_likes                                                      0
# actor_3_facebook_likes                                                     855
# actor_2_name                                                  Joel David Moore
# actor_1_facebook_likes                                                    1000
# gross                                                              7.60506e+08
# genres                                         Action|Adventure|Fantasy|Sci-Fi
# actor_1_name                                                       CCH Pounder
# movie_title                                                            Avatar
# ...

# %%
### Selecting two rows or more rows and all columns
df_movies.iloc[[0,4,8],:] # same as df_movies.iloc[[0,4,8]]
# Out:
#    color  director_name  num_critic_for_reviews  duration  \
# 0  Color  James Cameron                   723.0     178.0
# 4    NaN    Doug Walker                     NaN       NaN
# 8  Color    Joss Whedon                   635.0     141.0
#
#    director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                      0.0                   855.0   Joel David Moore
# 4                    131.0                     NaN         Rob Walker
# 8                      0.0                 19000.0  Robert Downey Jr.
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# 4                   131.0          NaN                      Documentary  ...
# 8                 26000.0  458991599.0          Action|Adventure|Sci-Fi  ...
#
#   num_user_for_reviews language  country  content_rating       budget  \
# ...

# %%
### Selecting n rows and m columns
df_movies.iloc[[0,4],[0,1,2]]
# Out:
#    color  director_name  num_critic_for_reviews
# 0  Color  James Cameron                   723.0
# 4    NaN    Doug Walker                     NaN

# %%
### This will give first 4 rows second to fourth columns
df_movies.iloc[0:4,1:4]
# Out:
#        director_name  num_critic_for_reviews  duration
# 0      James Cameron                   723.0     178.0
# 1     Gore Verbinski                   302.0     169.0
# 2         Sam Mendes                   602.0     148.0
# 3  Christopher Nolan                   813.0     164.0

# %%
df_movies.iloc[:,[4,5]] ## all rows and fifth and sixth column
# Out:
#       director_facebook_likes  actor_3_facebook_likes
# 0                         0.0                   855.0
# 1                       563.0                  1000.0
# 2                         0.0                   161.0
# 3                     22000.0                 23000.0
# 4                       131.0                     NaN
# ...                       ...                     ...
# 5038                      2.0                   318.0
# 5039                      NaN                   319.0
# 5040                      0.0                     0.0
# 5041                      0.0                   489.0
# 5042                     16.0                    16.0
#
# [5043 rows x 2 columns]

# %% [markdown]
# #### Let's say we want to select first 5 rows for the columns duration and gross without worrying about the integer index for the columns duration and gross, we can use loc instead of iloc

# %%
df_movies.loc[:5,['duration','gross']]
# Out:
#    duration        gross
# 0     178.0  760505847.0
# 1     169.0  309404152.0
# 2     148.0  200074175.0
# 3     164.0  448130642.0
# 4       NaN          NaN
# 5     132.0   73058679.0

# %%
### First four rows and all columns starting form duration and ending on gross
df_movies.loc[:5,'duration':'gross']
# Out:
#    duration  director_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      0.0                   855.0
# 1     169.0                    563.0                  1000.0
# 2     148.0                      0.0                   161.0
# 3     164.0                  22000.0                 23000.0
# 4       NaN                    131.0                     NaN
# 5     132.0                    475.0                   530.0
#
#        actor_2_name  actor_1_facebook_likes        gross
# 0  Joel David Moore                  1000.0  760505847.0
# 1     Orlando Bloom                 40000.0  309404152.0
# 2      Rory Kinnear                 11000.0  200074175.0
# 3    Christian Bale                 27000.0  448130642.0
# 4        Rob Walker                   131.0          NaN
# 5   Samantha Morton                   640.0   73058679.0

# %%
### First four rows and all columns after and including gross
df_movies.loc[:5,'gross':]
# Out:
#          gross                           genres     actor_1_name  \
# 0  760505847.0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1  309404152.0         Action|Adventure|Fantasy      Johnny Depp
# 2  200074175.0        Action|Adventure|Thriller  Christoph Waltz
# 3  448130642.0                  Action|Thriller        Tom Hardy
# 4          NaN                      Documentary      Doug Walker
# 5   73058679.0          Action|Adventure|Sci-Fi     Daryl Sabara
#
#                                          movie_title  num_voted_users  \
# 0                                            Avatar            886204
# 1          Pirates of the Caribbean: At World's End            471220
# 2                                           Spectre            275868
# 3                             The Dark Knight Rises           1144337
# 4  Star Wars: Episode VII - The Force Awakens    ...                8
# 5                                       John Carter            212204
#
# ...

# %% [markdown]
# ## You get the gist 🙂

# %% [markdown]
# ### Conditional Statements

# %%
df_movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %% [markdown]
# ### One condition: Movies directed by James Cameron

# %%
df_movies[df_movies['director_name']=='James Cameron']
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 0     Color  James Cameron                   723.0     178.0
# 26    Color  James Cameron                   315.0     194.0
# 288   Color  James Cameron                   210.0     153.0
# 291   Color  James Cameron                    94.0     141.0
# 606   Color  James Cameron                    82.0     171.0
# 2486  Color  James Cameron                   250.0     154.0
# 3575  Color  James Cameron                   204.0     107.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# 26                        0.0                   794.0       Kate Winslet
# 288                       0.0                   539.0  Jenette Goldstein
# 291                       0.0                   618.0        Tia Carrere
# 606                       0.0                   638.0         Todd Graff
# ...

# %% [markdown]
# ### Two conditions (AND): Movies directed by James Cameron & with imdb score above 8

# %%
df_movies[(df_movies['director_name']=='James Cameron') & (df_movies['imdb_score']>8)]
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 288   Color  James Cameron                   210.0     153.0
# 2486  Color  James Cameron                   250.0     154.0
# 3575  Color  James Cameron                   204.0     107.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 288                       0.0                   539.0  Jenette Goldstein
# 2486                      0.0                   604.0        Carrie Henn
# 3575                      0.0                   255.0     Brian Thompson
#
#       actor_1_facebook_likes        gross                   genres  ...  \
# 288                    780.0  204843350.0            Action|Sci-Fi  ...
# 2486                  2000.0   85200000.0  Action|Adventure|Sci-Fi  ...
# 3575                  2000.0   38400000.0            Action|Sci-Fi  ...
#
#      num_user_for_reviews language  country  content_rating       budget  \
# ...

# %% [markdown]
# ### Two conditions (OR): Movies directed by James Cameron | Sam Mendes

# %%
df_movies[(df_movies['director_name']=='James Cameron') | (df_movies['director_name']=='Sam Mendes')]
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 0     Color  James Cameron                   723.0     178.0
# 2     Color     Sam Mendes                   602.0     148.0
# 26    Color  James Cameron                   315.0     194.0
# 30    Color     Sam Mendes                   750.0     143.0
# 288   Color  James Cameron                   210.0     153.0
# 291   Color  James Cameron                    94.0     141.0
# 457   Color     Sam Mendes                   226.0     117.0
# 574   Color     Sam Mendes                   262.0     125.0
# 606   Color  James Cameron                    82.0     171.0
# 1114  Color     Sam Mendes                   323.0     119.0
# 2144  Color     Sam Mendes                   217.0      98.0
# 2486  Color  James Cameron                   250.0     154.0
# 2606  Color     Sam Mendes                   176.0     122.0
# 3493  Color     Sam Mendes                   750.0     143.0
# ...

# %% [markdown]
# ### Three conditions (AND,OR): Movies directed by James Cameron | Sam Mendes & imdb_score above 8

# %%
c1 = df_movies['imdb_score']>8
c2 = (df_movies['director_name']=='James Cameron') | (df_movies['director_name']=='Sam Mendes')
df_movies[ (c1) & (c2)]
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 288   Color  James Cameron                   210.0     153.0
# 2486  Color  James Cameron                   250.0     154.0
# 2606  Color     Sam Mendes                   176.0     122.0
# 3575  Color  James Cameron                   204.0     107.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 288                       0.0                   539.0  Jenette Goldstein
# 2486                      0.0                   604.0        Carrie Henn
# 2606                      0.0                   158.0    Peter Gallagher
# 3575                      0.0                   255.0     Brian Thompson
#
#       actor_1_facebook_likes        gross                   genres  ...  \
# 288                    780.0  204843350.0            Action|Sci-Fi  ...
# 2486                  2000.0   85200000.0  Action|Adventure|Sci-Fi  ...
# 2606                 18000.0  130058047.0                    Drama  ...
# ...

# %% [markdown]
# ## Statistics

# %%
df_movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
### describe gives a high level statistical summary
df_movies.describe()
# Out:
#        num_critic_for_reviews     duration  director_facebook_likes  \
# count             4993.000000  5028.000000              4939.000000
# mean               140.194272   107.201074               686.509212
# std                121.601675    25.197441              2813.328607
# min                  1.000000     7.000000                 0.000000
# 25%                 50.000000    93.000000                 7.000000
# 50%                110.000000   103.000000                49.000000
# 75%                195.000000   118.000000               194.500000
# max                813.000000   511.000000             23000.000000
#
#        actor_3_facebook_likes  actor_1_facebook_likes         gross  \
# count             5020.000000             5036.000000  4.159000e+03
# mean               645.009761             6560.047061  4.846841e+07
# std               1665.041728            15020.759120  6.845299e+07
# min                  0.000000                0.000000  1.620000e+02
# ...

# %% [markdown]
# ### Let's ask some questions now.

# %% [markdown]
# #### How many unique directors are in this dataframe?

# %%
df_movies['director_name'].nunique()
# Out:
# 2398

# %% [markdown]
# ### Top 5 directors to direct the most films

# %%
df_movies['director_name'].value_counts().nlargest(5) 
# just using value_counts will give the full summary
# value_counts(normalize=True) replaces the count with %
# Out:
# Steven Spielberg    26
# Woody Allen         22
# Martin Scorsese     20
# Clint Eastwood      20
# Ridley Scott        17
# Name: director_name, dtype: int64

# %% [markdown]
# ### Which directors made movies with high ratings

# %%
### From the describe we see that the 75th percentile of imdb score is 7.2
df_movies[df_movies['imdb_score']>7.2]['director_name'].value_counts()
# Out:
# Steven Spielberg       17
# Martin Scorsese        14
# Clint Eastwood         11
# David Fincher           8
# Woody Allen             8
#                        ..
# Sylvain Chomet          1
# Oliver Hirschbiegel     1
# Lukas Moodysson         1
# William Wyler           1
# Carol Reed              1
# Name: director_name, Length: 656, dtype: int64
